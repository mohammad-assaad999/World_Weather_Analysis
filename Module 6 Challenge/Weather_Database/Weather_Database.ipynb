# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests
from config import g_key
from config import weather_api_key
from datetime import datetime

# %%
lat=np.random.uniform(-90,90,2000)
lng=np.random.uniform(-180,180,2000)
lat_lng=zip(lat,lng)
lat_lng

# %%
coordinates = list(lat_lng)

# %%
cities=[]
for coordinate in coordinates:
    city =citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 745

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55fd565afc65bd1cff73756cb209c91a

# %%
city_url = url + "&q=" + city 
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=55fd565afc65bd1cff73756cb209c91a&q=puerto ayora

# %%
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
weather_data = city_weather.json()
weather_data
# Out:
# {'coord': {'lon': -90.3518, 'lat': -0.7393},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 73.54,
#   'feels_like': 74.7,
#   'temp_min': 73.54,
#   'temp_max': 73.54,
#   'pressure': 1014,
#   'humidity': 87},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 147, 'gust': 5.99},
#  'clouds': {'all': 80},
#  'dt': 1623207358,
#  'sys': {'type': 2,
#   'id': 2005652,
#   'country': 'EC',
#   'sunrise': 1623153498,
#   'sunset': 1623196981},
#  'timezone': -21600,
#  'id': 3652764,
#  'name': 'Puerto Ayora',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=weather_data["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ord 43 of Set 6 | poronaysk
# Processing Record 44 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | onguday
# Processing Record 47 of Set 6 | tromso
# Processing Record 48 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 49 of Set 6 | rio grande
# Processing Record 50 of Set 6 | ondjiva
# Processing Record 1 of Set 7 | solnechnyy
# Processing Record 2 of Set 7 | rawson
# Processing Record 3 of Set 7 | morant bay
# Processing Record 4 of Set 7 | ende
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | walvis bay
# Processing Record 7 of Set 7 | nuqui
# Processing Record 8 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 7 | freeport
# Processing Record 10 of Set 7 | nylstroom
# City not found. Skipping...
# Processing Record 11 of Set 7 | baraya
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | nam tha
# City not found. Skipping...
# Processing Record 14 of Set 7 | sukumo
# Processing Record 15 of Set 7 | omboue
# Processing Record 16 of Set 7 | tuy hoa
# Processing Record 17 of Set 7 | seoul
# Processing Record 18 of Set 7 | manzhouli
# Processing Record 19 of Set 7 | kyren
# Processing Record 20 of Set 7 | moose factory
# Processing Record 21 of Set 7 | paamiut
# Processing Record 22 of Set 7 | vila velha
# Processing Record 23 of Set 7 | manaus
# Processing Record 24 of Set 7 | oksfjord
# Processing Record 25 of Set 7 | verkhoyansk
# Processing Record 26 of Set 7 | tall kayf
# Processing Record 27 of Set 7 | padang
# Processing Record 28 of Set 7 | srandakan
# Processing Record 29 of Set 7 | sayyan
# Processing Record 30 of Set 7 | zacatepec
# Processing Record 31 of Set 7 | pyaozerskiy
# Processing Record 32 of Set 7 | mbaiki
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | senador jose porfirio
# Processing Record 35 of Set 7 | mangrol
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 7 | bayir
# Processing Record 39 of Set 7 | mut
# Processing Record 40 of Set 7 | trincomalee
# Processing Record 41 of Set 7 | lubao
# Processing Record 42 of Set 7 | wagar
# Processing Record 43 of Set 7 | steamboat springs
# Processing Record 44 of Set 7 | santa maria
# Processing Record 45 of Set 7 | minudasht
# Processing Record 46 of Set 7 | nyurba
# Processing Record 47 of Set 7 | lunel
# Processing Record 48 of Set 7 | kargil
# Processing Record 49 of Set 7 | sibolga
# Processing Record 50 of Set 7 | hualmay
# Processing Record 1 of Set 8 | inverness
# Processing Record 2 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 8 | svetlaya
# Processing Record 4 of Set 8 | ekhabi
# Processing Record 5 of Set 8 | udachnyy
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | saleilua
# City not found. Skipping...
# Processing Record 8 of Set 8 | moranbah
# Processing Record 9 of Set 8 | karratha
# Processing Record 10 of Set 8 | kawanoe
# Processing Record 11 of Set 8 | mayo
# Processing Record 12 of Set 8 | gambo
# Processing Record 13 of Set 8 | sumbe
# Processing Record 14 of Set 8 | tatsinskaya
# City not found. Skipping...
# Processing Record 15 of Set 8 | wawa
# Processing Record 16 of Set 8 | zhucheng
# Processing Record 17 of Set 8 | shimoda
# Processing Record 18 of Set 8 | dakar
# Processing Record 19 of Set 8 | nishihara
# Processing Record 20 of Set 8 | axim
# Processing Record 21 of Set 8 | baker city
# Processing Record 22 of Set 8 | huadian
# Processing Record 23 of Set 8 | sakakah
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | funehiki
# Processing Record 26 of Set 8 | rexburg
# Processing Record 27 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 8 | le port
# Processing Record 29 of Set 8 | alofi
# Processing Record 30 of Set 8 | quelimane
# Processing Record 31 of Set 8 | timbiras
# Processing Record 32 of Set 8 | oistins
# Processing Record 33 of Set 8 | jacareacanga
# Processing Record 34 of Set 8 | paita
# Processing Record 35 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 8 | new ulm
# Processing Record 37 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 8 | goure
# Processing Record 39 of Set 8 | tari
# Processing Record 40 of Set 8 | vostok
# Processing Record 41 of Set 8 | olafsvik
# Processing Record 42 of Set 8 | oranjestad
# Processing Record 43 of Set 8 | kedrovyy
# Processing Record 44 of Set 8 | natal
# Processing Record 45 of Set 8 | baykit
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | longyearbyen
# Processing Record 48 of Set 8 | bela
# Processing Record 49 of Set 8 | gubkinskiy
# Processing Record 50 of Set 8 | nanakuli
# Processing Record 1 of Set 9 | hay river
# Processing Record 2 of Set 9 | port blair
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | ankang
# Processing Record 5 of Set 9 | sorong
# Processing Record 6 of Set 9 | broken hill
# Processing Record 7 of Set 9 | borogontsy
# Processing Record 8 of Set 9 | bonthe
# Processing Record 9 of Set 9 | port moresby
# Processing Record 10 of Set 9 | birecik
# Processing Record 11 of Set 9 | ust-ishim
# Processing Record 12 of Set 9 | rapar
# Processing Record 13 of Set 9 | luderitz
# Processing Record 14 of Set 9 | benguela
# Processing Record 15 of Set 9 | olinda
# Processing Record 16 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 9 | hambantota
# Processing Record 18 of Set 9 | norman wells
# Processing Record 19 of Set 9 | huilong
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | mitchell
# Processing Record 22 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 9 | ceres
# Processing Record 24 of Set 9 | kruisfontein
# Processing Record 25 of Set 9 | college
# Processing Record 26 of Set 9 | escanaba
# Processing Record 27 of Set 9 | banamba
# Processing Record 28 of Set 9 | merrill
# Processing Record 29 of Set 9 | khatanga
# Processing Record 30 of Set 9 | pundaguitan
# Processing Record 31 of Set 9 | nerchinskiy zavod
# Processing Record 32 of Set 9 | komsomolskiy
# Processing Record 33 of Set 9 | nikel
# Processing Record 34 of Set 9 | dalvik
# Processing Record 35 of Set 9 | athabasca
# Processing Record 36 of Set 9 | mitsamiouli
# Processing Record 37 of Set 9 | saint-augustin
# Processing Record 38 of Set 9 | chunskiy
# Processing Record 39 of Set 9 | provost
# Processing Record 40 of Set 9 | avarua
# Processing Record 41 of Set 9 | floriano
# Processing Record 42 of Set 9 | hailey
# Processing Record 43 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 44 of Set 9 | vero beach
# Processing Record 45 of Set 9 | penzance
# Processing Record 46 of Set 9 | emerald
# Processing Record 47 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 9 | markapur
# Processing Record 49 of Set 9 | bay city
# Processing Record 50 of Set 9 | bull savanna
# Processing Record 1 of Set 10 | leningradskiy
# Processing Record 2 of Set 10 | erzin
# Processing Record 3 of Set 10 | escarcega
# Processing Record 4 of Set 10 | kansanshi
# Processing Record 5 of Set 10 | hanumangarh
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | ibra
# Processing Record 8 of Set 10 | champerico
# Processing Record 9 of Set 10 | thompson
# Processing Record 10 of Set 10 | seminole
# Processing Record 11 of Set 10 | zatoka
# Processing Record 12 of Set 10 | demyansk
# Processing Record 13 of Set 10 | mgachi
# Processing Record 14 of Set 10 | akyab
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | madimba
# Processing Record 17 of Set 10 | russell
# Processing Record 18 of Set 10 | ajdabiya
# Processing Record 19 of Set 10 | prince rupert
# Processing Record 20 of Set 10 | lima
# Processing Record 21 of Set 10 | alta floresta
# Processing Record 22 of Set 10 | chernyshevskiy
# Processing Record 23 of Set 10 | fresnillo
# Processing Record 24 of Set 10 | guerrero negro
# Processing Record 25 of Set 10 | belaya gora
# Processing Record 26 of Set 10 | bathsheba
# Processing Record 27 of Set 10 | tabou
# Processing Record 28 of Set 10 | sistranda
# Processing Record 29 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | vanimo
# Processing Record 33 of Set 10 | mildura
# Processing Record 34 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 10 | broome
# Processing Record 36 of Set 10 | kurumkan
# Processing Record 37 of Set 10 | port lincoln
# Processing Record 38 of Set 10 | vao
# Processing Record 39 of Set 10 | atar
# Processing Record 40 of Set 10 | codrington
# Processing Record 41 of Set 10 | savelugu
# Processing Record 42 of Set 10 | tual
# Processing Record 43 of Set 10 | valparaiso
# Processing Record 44 of Set 10 | ferzikovo
# Processing Record 45 of Set 10 | noumea
# Processing Record 46 of Set 10 | provideniya
# Processing Record 47 of Set 10 | morondava
# Processing Record 48 of Set 10 | eura
# Processing Record 49 of Set 10 | bambamarca
# Processing Record 50 of Set 10 | eyl
# Processing Record 1 of Set 11 | conde
# Processing Record 2 of Set 11 | jalu
# Processing Record 3 of Set 11 | gold coast
# Processing Record 4 of Set 11 | lorengau
# Processing Record 5 of Set 11 | ozernovskiy
# Processing Record 6 of Set 11 | hasaki
# Processing Record 7 of Set 11 | pennagaram
# Processing Record 8 of Set 11 | corrales
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | sabang
# Processing Record 11 of Set 11 | eten
# Processing Record 12 of Set 11 | tupik
# Processing Record 13 of Set 11 | ola
# Processing Record 14 of Set 11 | shenjiamen
# Processing Record 15 of Set 11 | carndonagh
# Processing Record 16 of Set 11 | santa ana
# Processing Record 17 of Set 11 | ust-kuyga
# Processing Record 18 of Set 11 | avera
# Processing Record 19 of Set 11 | rosetta
# Processing Record 20 of Set 11 | khor
# Processing Record 21 of Set 11 | lithgow
# Processing Record 22 of Set 11 | zeya
# Processing Record 23 of Set 11 | sergeyevka
# Processing Record 24 of Set 11 | abu kamal
# Processing Record 25 of Set 11 | virginia beach
# Processing Record 26 of Set 11 | shelburne
# Processing Record 27 of Set 11 | bucovat
# Processing Record 28 of Set 11 | vettavalam
# Processing Record 29 of Set 11 | geoagiu
# Processing Record 30 of Set 11 | haines junction
# Processing Record 31 of Set 11 | santa isabel do rio negro
# Processing Record 32 of Set 11 | telde
# Processing Record 33 of Set 11 | alexandria
# Processing Record 34 of Set 11 | vardo
# Processing Record 35 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 11 | verkhnyaya inta
# Processing Record 37 of Set 11 | thinadhoo
# Processing Record 38 of Set 11 | kosa
# Processing Record 39 of Set 11 | jiujiang
# Processing Record 40 of Set 11 | gornopravdinsk
# Processing Record 41 of Set 11 | lishui
# Processing Record 42 of Set 11 | omsukchan
# Processing Record 43 of Set 11 | lexington
# Processing Record 44 of Set 11 | gujranwala
# Processing Record 45 of Set 11 | chaiyaphum
# Processing Record 46 of Set 11 | gainesville
# Processing Record 47 of Set 11 | salta
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | takaka
# Processing Record 50 of Set 11 | malinovoye ozero
# Processing Record 1 of Set 12 | wanaka
# Processing Record 2 of Set 12 | murgab
# Processing Record 3 of Set 12 | dimitrie cantemir
# Processing Record 4 of Set 12 | magog
# Processing Record 5 of Set 12 | bagdarin
# Processing Record 6 of Set 12 | ulaanbaatar
# Processing Record 7 of Set 12 | chuzhou
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | sobolevo
# Processing Record 10 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 12 | port hardy
# Processing Record 12 of Set 12 | les cayes
# Processing Record 13 of Set 12 | shache
# Processing Record 14 of Set 12 | pangnirtung
# Processing Record 15 of Set 12 | moerai
# Processing Record 16 of Set 12 | spring valley
# Processing Record 17 of Set 12 | utete
# Processing Record 18 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 12 | mbini
# Processing Record 21 of Set 12 | kyzyl-suu
# Processing Record 22 of Set 12 | blagoyevo
# Processing Record 23 of Set 12 | kirovskiy
# Processing Record 24 of Set 12 | salalah
# Processing Record 25 of Set 12 | tezze sul brenta
# Processing Record 26 of Set 12 | kuah
# Processing Record 27 of Set 12 | pasighat
# Processing Record 28 of Set 12 | sinop
# Processing Record 29 of Set 12 | mount gambier
# Processing Record 30 of Set 12 | charlestown
# Processing Record 31 of Set 12 | lagoa
# Processing Record 32 of Set 12 | acapulco
# Processing Record 33 of Set 12 | sabla
# Processing Record 34 of Set 12 | bintulu
# Processing Record 35 of Set 12 | hudson bay
# Processing Record 36 of Set 12 | isangel
# Processing Record 37 of Set 12 | quilmana
# Processing Record 38 of Set 12 | majene
# Processing Record 39 of Set 12 | constantine
# Processing Record 40 of Set 12 | palmer
# Processing Record 41 of Set 12 | waipawa
# Processing Record 42 of Set 12 | pag
# Processing Record 43 of Set 12 | bairiki
# Processing Record 44 of Set 12 | adelaide
# Processing Record 45 of Set 12 | kismayo
# Processing Record 46 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 12 | aksu
# Processing Record 48 of Set 12 | praya
# Processing Record 49 of Set 12 | myitkyina
# Processing Record 50 of Set 12 | mantua
# Processing Record 1 of Set 13 | clarence town
# Processing Record 2 of Set 13 | sarangani
# Processing Record 3 of Set 13 | smithers
# Processing Record 4 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 13 | moctezuma
# Processing Record 6 of Set 13 | medeiros neto
# Processing Record 7 of Set 13 | lipari
# Processing Record 8 of Set 13 | makakilo city
# Processing Record 9 of Set 13 | dubovyy umet
# Processing Record 10 of Set 13 | itaituba
# Processing Record 11 of Set 13 | darnah
# Processing Record 12 of Set 13 | timmins
# Processing Record 13 of Set 13 | plettenberg bay
# Processing Record 14 of Set 13 | iquitos
# Processing Record 15 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 13 | dalby
# Processing Record 17 of Set 13 | vuktyl
# Processing Record 18 of Set 13 | kishi
# Processing Record 19 of Set 13 | carballo
# Processing Record 20 of Set 13 | bay roberts
# Processing Record 21 of Set 13 | awjilah
# Processing Record 22 of Set 13 | saint-francois
# Processing Record 23 of Set 13 | point fortin
# Processing Record 24 of Set 13 | partenit
# Processing Record 25 of Set 13 | ambilobe
# Processing Record 26 of Set 13 | oum hadjer
# Processing Record 27 of Set 13 | sorland
# Processing Record 28 of Set 13 | kondinskoye
# Processing Record 29 of Set 13 | fare
# Processing Record 30 of Set 13 | clermont
# Processing Record 31 of Set 13 | garissa
# Processing Record 32 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 13 | kamenka
# Processing Record 34 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 35 of Set 13 | comodoro rivadavia
# Processing Record 36 of Set 13 | maltahohe
# Processing Record 37 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 13 | kalevala
# Processing Record 39 of Set 13 | gao
# Processing Record 40 of Set 13 | guaranesia
# Processing Record 41 of Set 13 | florianopolis
# Processing Record 42 of Set 13 | phalaborwa
# Processing Record 43 of Set 13 | bahir dar
# Processing Record 44 of Set 13 | plouzane
# Processing Record 45 of Set 13 | romans-sur-isere
# Processing Record 46 of Set 13 | chegdomyn
# Processing Record 47 of Set 13 | humaita
# Processing Record 48 of Set 13 | kuytun
# Processing Record 49 of Set 13 | guayaramerin
# Processing Record 50 of Set 13 | wageningen
# Processing Record 1 of Set 14 | shablykino
# Processing Record 2 of Set 14 | weston
# Processing Record 3 of Set 14 | dawei
# Processing Record 4 of Set 14 | yar-sale
# Processing Record 5 of Set 14 | yeghegnavan
# Processing Record 6 of Set 14 | jijiga
# Processing Record 7 of Set 14 | klaebu
# Processing Record 8 of Set 14 | araouane
# Processing Record 9 of Set 14 | yarmouth
# Processing Record 10 of Set 14 | miguel alves
# Processing Record 11 of Set 14 | launceston
# Processing Record 12 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 13 of Set 14 | chaohu
# Processing Record 14 of Set 14 | haicheng
# Processing Record 15 of Set 14 | sumenep
# Processing Record 16 of Set 14 | shaunavon
# Processing Record 17 of Set 14 | praia
# Processing Record 18 of Set 14 | raudeberg
# Processing Record 19 of Set 14 | priekule
# Processing Record 20 of Set 14 | ikornnes
# Processing Record 21 of Set 14 | parfenyevo
# Processing Record 22 of Set 14 | hollola
# Processing Record 23 of Set 14 | quatre cocos
# Processing Record 24 of Set 14 | quarai
# Processing Record 25 of Set 14 | ballitoville
# Processing Record 26 of Set 14 | havoysund
# Processing Record 27 of Set 14 | hovd
# Processing Record 28 of Set 14 | marsa matruh
# Processing Record 29 of Set 14 | deputatskiy
# Processing Record 30 of Set 14 | lovozero
# Processing Record 31 of Set 14 | vavoua
# Processing Record 32 of Set 14 | tornio
# Processing Record 33 of Set 14 | borazjan
# Processing Record 34 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 14 | qingdao
# Processing Record 36 of Set 14 | rio verde de mato grosso
# Processing Record 37 of Set 14 | newport
# Processing Record 38 of Set 14 | freising
# Processing Record 39 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 40 of Set 14 | windhoek
# Processing Record 41 of Set 14 | camacha
# Processing Record 42 of Set 14 | hjelset
# Processing Record 43 of Set 14 | terrace
# Processing Record 44 of Set 14 | shchelkun
# Processing Record 45 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 46 of Set 14 | aktash
# Processing Record 47 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 14 | kholodnyy
# Processing Record 49 of Set 14 | santa marta de tormes
# Processing Record 50 of Set 14 | oxelosund
# Processing Record 1 of Set 15 | olkhovka
# Processing Record 2 of Set 15 | paka
# Processing Record 3 of Set 15 | iralaya
# Processing Record 4 of Set 15 | abu zabad
# Processing Record 5 of Set 15 | talcahuano
# Processing Record 6 of Set 15 | boa vista
# Processing Record 7 of Set 15 | casablanca
# Processing Record 8 of Set 15 | bowen
# Processing Record 9 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 15 | tombouctou
# Processing Record 11 of Set 15 | nizwa
# Processing Record 12 of Set 15 | ashqelon
# Processing Record 13 of Set 15 | medvezhyegorsk
# Processing Record 14 of Set 15 | port hedland
# Processing Record 15 of Set 15 | el tigre
# Processing Record 16 of Set 15 | cabra
# Processing Record 17 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 15 | imeni poliny osipenko
# Processing Record 19 of Set 15 | nanma
# Processing Record 20 of Set 15 | baruun-urt
# Processing Record 21 of Set 15 | tura
# Processing Record 22 of Set 15 | gat
# Processing Record 23 of Set 15 | sao miguel do araguaia
# Processing Record 24 of Set 15 | kropotkin
# Processing Record 25 of Set 15 | magaria
# Processing Record 26 of Set 15 | namtsy
# Processing Record 27 of Set 15 | kalmunai
# Processing Record 28 of Set 15 | strzelce opolskie
# Processing Record 29 of Set 15 | nakhon thai
# Processing Record 30 of Set 15 | port macquarie
# Processing Record 31 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 15 | snasa
# Processing Record 33 of Set 15 | luebo
# Processing Record 34 of Set 15 | guilin
# Processing Record 35 of Set 15 | catemaco
# Processing Record 36 of Set 15 | troitsko-pechorsk
# Processing Record 37 of Set 15 | turukhansk
# Processing Record 38 of Set 15 | laguna
# Processing Record 39 of Set 15 | orlik
# Processing Record 40 of Set 15 | cayenne
# Processing Record 41 of Set 15 | salisbury
# Processing Record 42 of Set 15 | buala
# Processing Record 43 of Set 15 | ilebo
# Processing Record 44 of Set 15 | rongcheng
# Processing Record 45 of Set 15 | caravelas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia -54.8000  -68.3000     49.66        46          40
# 1          Te Anau -45.4167  167.7167     54.01        78          96
# 2           Dikson  73.5069   80.5464     31.68        94          98
# 3            Vaini -21.2000 -175.2000     71.76        88          75
# 4        Gualeguay -33.1416  -59.3097     54.54        93          51
# 5       Nikolskoye  59.7035   30.7861     58.80        65          98
# 6          Ahipara -35.1667  173.1667     65.77        73          26
# 7           Barrow  71.2906 -156.7887     34.20        85         100
# 8         Cidreira -30.1811  -50.2056     62.42        92         100
# 9  Bambous Virieux -20.3428   57.7575     70.05        88          75
#
#    Wind Speed Country Current Description
# 0       14.97      AR       broken clouds
# 1        1.05      NZ       broken clouds
# 2       15.46      RU       broken clouds
# 3       12.66      TO       broken clouds
# 4        5.70      AR       broken clouds
# 5        3.02      RU       broken clouds
# 6        6.76      NZ       broken clouds
# 7       15.68      US       broken clouds
# 8       15.73      BR       broken clouds
# 9       16.28      MU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     49.66        46          40
# 1          Te Anau      NZ -45.4167  167.7167     54.01        78          96
# 2           Dikson      RU  73.5069   80.5464     31.68        94          98
# 3            Vaini      TO -21.2000 -175.2000     71.76        88          75
# 4        Gualeguay      AR -33.1416  -59.3097     54.54        93          51
# 5       Nikolskoye      RU  59.7035   30.7861     58.80        65          98
# 6          Ahipara      NZ -35.1667  173.1667     65.77        73          26
# 7           Barrow      US  71.2906 -156.7887     34.20        85         100
# 8         Cidreira      BR -30.1811  -50.2056     62.42        92         100
# 9  Bambous Virieux      MU -20.3428   57.7575     70.05        88          75
#
#    Wind Speed Current Description
# 0       14.97       broken clouds
# 1        1.05       broken clouds
# 2       15.46       broken clouds
# 3       12.66       broken clouds
# 4        5.70       broken clouds
# 5        3.02       broken clouds
# 6        6.76       broken clouds
# 7       15.68       broken clouds
# 8       15.73       broken clouds
# 9       16.28       broken clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
